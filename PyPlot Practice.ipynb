# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
apple_data = pd.read_csv('AAPL.csv')
apple_data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2019-05-14  186.410004  189.699997  185.410004  188.660004  186.434998
# 1    2019-05-15  186.270004  191.750000  186.020004  190.919998  188.668335
# 2    2019-05-16  189.910004  192.470001  188.839996  190.080002  187.838257
# 3    2019-05-17  186.929993  190.899994  186.759995  189.000000  186.770996
# 4    2019-05-20  183.520004  184.350006  180.279999  183.089996  180.930695
# ..          ...         ...         ...         ...         ...         ...
# 248  2020-05-07  303.220001  305.170013  301.970001  303.739990  302.919983
# 249  2020-05-08  305.640015  310.350006  304.290009  310.130005  310.130005
# 250  2020-05-11  308.100006  317.049988  307.239990  315.010010  315.010010
# 251  2020-05-12  317.829987  319.690002  310.910004  311.410004  311.410004
# 252  2020-05-13  312.149994  315.950012  303.209991  307.649994  307.649994
#
#        Volume
# 0    36529700
# 1    26544700
# ...

# %%
dates = apple_data['Date']
open = apple_data['Open']
high = apple_data['High']
low = apple_data['Low']
close = apple_data['Close']

# %%
plt.plot(dates,close)
plt.plot(dates,open)
plt.show()

# %%
plt.plot(dates, high)
plt.plot(dates, low)
plt.show()

# %%
fig = plt.figure()
plt.subplot(411)
plt.plot(dates,open)
plt.subplot(412)
plt.plot(dates,close)
plt.subplot(413)
plt.plot(dates,high)
plt.subplot(414)
plt.plot(dates,low)
plt.show()

# %%
figure,axes = plt.subplots(2,2)
axes[0,0].plot(dates,open)
axes[0,1].plot(dates,close)
axes[1,0].plot(dates,high)
axes[1,1].plot(dates,low)
plt.show()

# %%
#labeling
plt.plot(dates,close)
plt.title('ClosePrices of AAPL')
plt.xlabel('Dates')
plt.ylabel('Prices in USD')
plt.xticks(pd.date_range('2019-05-14','2020-05-13',5).strftime('%Y-%m-%d'))
plt.show()

# %%
figure,axes = plt.subplots(1,2)
fig.suptitle('AAPL Prices',y=.005)
axes[0].plot(dates,high)
axes[0].set_title('Highs for AAPL')
axes[0].set_ylabel('Price')
axes[0].set_xlabel('Date')
axes[1].set_title('Lows for AAPL')
axes[1].set_ylabel('Price')
axes[1].set_xlabel('Date')
axes[1].plot(dates,low)
plt.tight_layout()
plt.show()

# %%
plt.plot(dates,high)
plt.plot(dates,low)
plt.title('Daily High and Low of AAPL')
plt.xlabel('Dates')
plt.ylabel('Prices in USD')
plt.xticks(pd.date_range('2019-05-14','2020-05-13',5).strftime('%Y-%m-%d'))
plt.legend(['High','Low'])
plt.show()

# %%
plt.scatter(dates,close)
plt.show()

# %%
plt.stackplot(dates, (high,low))
plt.show()

# %%
plt.hist(high, bins=30)
plt.show()
